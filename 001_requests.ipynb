# %%
# Do %uv pip install python-dotenv in the terminal
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\Projects\Claude\.venv\Scripts\python.exe: No module named uv

# %%
# Load env variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from anthropic import Anthropic

client=Anthropic()
model="claude-opus-5"

# %%
# Make a request
message=client.messages.create(
    model=model,
    max_tokens=1000,
    messages=[
        {"role":"user",
         "content":"What is astrophysics all about. Answer in one sentence"
        }

    ]
)

# %%
message
# Out:
# Message(id='msg_011CeGhq1Uj1BgbYAMycrjws', container=None, content=[ThinkingBlock(signature='...', thinking='', type='thinking'), TextBlock(citations=None, text='Astrophysics is the branch of science that applies the laws of physics and chemistry to understand the nature, origin, structure, and evolution of celestial objects — stars, planets, galaxies, black holes — and the universe as a whole.', type='text')], model='claude-opus-5', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='global', input_tokens=24, output_tokens=96, output_tokens_details=OutputTokensDetails(thinking_tokens=20), server_tool_use=None, service_tier='standard'))

# %%
message.content[1].text
# Out:
# 'Astrophysics is the branch of science that applies the laws of physics and chemistry to understand the nature, origin, structure, and evolution of celestial objects — stars, planets, galaxies, black holes — and the universe as a whole.'
