# %%
# Load env variables
from dotenv import load_dotenv
load_dotenv()

# %%
from anthropic import Anthropic

client=Anthropic()
model="claude-opus-5"

# %%
def add_user_message(messages, text):
    user_message={"role":"user", "content":text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message={"role":"assistant", "content":text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=None):
    params={
        "model":model,
        "max_tokens":1000,
        "messages":messages
    }

    #We only add system and temperature as parameters if they are defined
    if system is not None:
        params["system"]=system

    if temperature is not None:
            params["temperature"]=temperature

    message=client.messages.create(
        **params
    )
    print(message)
    for block in message.content:
        if block.type=='text':
            return block.text

# %%
messages=[]
add_user_message(messages, "Write a Py Function that checks a string for duplicate characters.")

#Can add temperature for creativity and system prompts for adjusting Claude's behaviour
answer=chat(messages, system="You are a pythone engineer who writes very concise code", temperature=0.0)

answer
# Out:
# Message(id='msg_011CeJfhpqr32qPS6WWdcR1B', container=None, content=[ThinkingBlock(signature='...', thinking='', type='thinking'), TextBlock(citations=None, text='```python\ndef has_duplicates(s):\n    return len(set(s)) < len(s)\n```\n\n**Variant — return the duplicated characters:**\n\n```python\nfrom collections import Counter\n\ndef duplicates(s):\n    return {c for c, n in Counter(s).items() if n > 1}\n```\n\n**Variant — early exit (fastest for long strings with early dupes):**\n\n```python\ndef has_duplicates(s):\n    seen = set()\n    return any(c in seen or seen.add(c) for c in s)\n```', type='text')], model='claude-opus-5', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='global', input_tokens=43, output_tokens=186, output_tokens_details=OutputTokensDetails(t
# ...
